# %%
from scipy import misc
import imageio
f = imageio.imread("Pictures\\pk2.jpg")
#imageio.imsave("C:\\Users\\DELL\\Pictures\\Camera Roll\\pk1.jpg", f) # uses the Image module (PIL)

import matplotlib.pyplot as plt
plt.imshow(f)
plt.show()
f.shape,f.dtype
# Out:
# ((713, 535, 3), dtype('uint8'))
